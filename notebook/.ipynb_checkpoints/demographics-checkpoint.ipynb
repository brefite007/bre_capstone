# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
location = pd.read_csv('../data/demo_location.csv')
location
# Out:
#     Year   Location  Total            Food Type
# 0   2019  Northeast   19.4         Food At Home
# 1   2019    Midwest   20.5         Food At Home
# 2   2019      South   35.7         Food At Home
# 3   2019       West   24.3         Food At Home
# 4   2019  Northeast   18.6  Food Away From Home
# 5   2019    Midwest   19.3  Food Away From Home
# 6   2019      South   36.0  Food Away From Home
# 7   2019       West   26.0  Food Away From Home
# 8   2019  Northeast   19.8  Alcoholic Beverages
# 9   2019    Midwest   21.1  Alcoholic Beverages
# 10  2019      South   34.0  Alcoholic Beverages
# 11  2019       West   25.1  Alcoholic Beverages
# 12  2020  Northeast   20.4         Food At Home
# 13  2020    Midwest   20.2         Food At Home
# 14  2020      South   34.5         Food At Home
# 15  2020       West   25.6         Food At Home
# 16  2020  Northeast   18.2  Food Away From Home
# 17  2020    Midwest   20.3  Food Away From Home
# 18  2020      South   35.5  Food Away From Home
# ...

# %%
avg_location = location.groupby(['Location', 'Food Type'])['Total'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_location, x='Location', y='Total', hue='Food Type')
plt.title('Average Annual Food & Beverage Expenditure by Region (2019-2023)', fontsize=14)
plt.ylabel('Avg Annual Spending (Millions)')
plt.xlabel('Region')
plt.legend(title='Food & Beverage Type')
plt.tight_layout()
plt.savefig('food_bev_expend_region.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
avg_df = pd.read_csv('../data/demo_age.csv')
avg_df
# Out:
#      Year                 Type    Age  Total
# 0    2019         Food At Home   0-24    4.1
# 1    2019         Food At Home  25-34   15.2
# 2    2019         Food At Home  35-44   19.9
# 3    2019         Food At Home  45-54   20.9
# 4    2019         Food At Home  55-64   19.6
# ..    ...                  ...    ...    ...
# 100  2023  Alcoholic Beverages  35-44   19.0
# 101  2023  Alcoholic Beverages  45-54   21.2
# 102  2023  Alcoholic Beverages  55-64   20.1
# 103  2023  Alcoholic Beverages  65-74   14.8
# 104  2023  Alcoholic Beverages    75+    6.5
#
# [105 rows x 4 columns]

# %%
df_away = avg_df[avg_df['Type'] == 'Food Away From Home']

# %%
df_away['Year'] = df_away['Year'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11472\2399954124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_away['Year'] = df_away['Year'].astype(str)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_away, x='Year', y='Total', hue='Age', marker='o')
plt.title('Average Food Away From Home Spending by Age Overtime')
plt.xlabel('Year')
plt.ylabel('Avg Spending (Millions)')
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('food_away_from_home_by_age.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_alcohol = avg_df[avg_df['Type'] == 'Alcoholic Beverages']

# %%
df_alcohol['Year'] = df_alcohol['Year'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11472\2481562598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alcohol['Year'] = df_alcohol['Year'].astype(str)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_alcohol, x='Year', y='Total', hue='Age', marker='o')
plt.title('Average Alcoholic Beverage Spending by Age Overtime', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Avg Spending (Millions)')
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('alcoholic_bev_by_age.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_home = avg_df[avg_df['Type'] == 'Food At Home']

# %%
df_home['Year'] = df_home['Year'].astype(str)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11472\267072608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_home['Year'] = df_home['Year'].astype(str)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_home, x='Year', y='Total', hue='Age', marker='o')
plt.title('Average Food At Home Spending by Age Overtime', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Avg Spending (Millions)')
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('food_at_home_by_age.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
income = pd.read_csv('../data/demo_income.csv')
income.head()
# Out:
#    Year          Type Income  Total
# 0  2019  Food At Home   0-14    5.8
# 1  2019  Food At Home  15-29   10.2
# 2  2019  Food At Home  30-39    7.4
# 3  2019  Food At Home  40-49    8.2
# 4  2019  Food At Home  50-69   13.0

# %%
income_order = ['0-14', '15-29', '30-39', '40-49', '50-69', '70-99', '100-149', '150-199', '200+']

# %%
relevant_types = ['Food At Home', 'Food Away From Home', 'Alcoholic Beverages']
subset = income[income['Type'].isin(relevant_types)]

# %%
subset['Income'] = pd.Categorical(subset['Income'], categories=income_order, ordered=True)

# %%
avg_spending = subset.groupby(['Income', 'Type'])['Total'].mean().reset_index()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11472\2421114271.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_spending = subset.groupby(['Income', 'Type'])['Total'].mean().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=avg_spending, x='Income', y='Total', hue='Type')

plt.title('Average Annual Spending on Food and Alcohol by Income')
plt.xlabel('Income Before Taxes ($1000s)')
plt.ylabel('Avg Spending (Millions)')
plt.xticks(rotation=45)
plt.legend(title='Spending Category')
plt.tight_layout()
plt.savefig('avg_ann_spend_food_alc.png', dpi=300, bbox_inches='tight')
plt.show()
