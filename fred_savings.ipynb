# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fred = pd.read_csv('../data/fred_savings.csv')

# %%
fred
# Out:
#     observation_date  PSAVERT
# 0         2015-01-01      6.3
# 1         2015-02-01      6.4
# 2         2015-03-01      5.9
# 3         2015-04-01      5.9
# 4         2015-05-01      5.8
# ..               ...      ...
# 115       2024-08-01      4.2
# 116       2024-09-01      3.8
# 117       2024-10-01      4.0
# 118       2024-11-01      3.7
# 119       2024-12-01      3.3
#
# [120 rows x 2 columns]

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user\Desktop\Capstone\notebook
